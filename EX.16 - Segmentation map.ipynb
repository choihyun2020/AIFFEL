# %% [markdown]
# # 16. Segmentation map으로 도로 이미지 만들기

# %%
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/cityscapes/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1001

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    original = img[:, w:, :] 
    original = tf.cast(original, tf.float32)
    return normalize(sketch), normalize(original)

f = data_path + os.listdir(data_path)[1]
sketch, original = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(original))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, original):
    stacked = tf.concat([sketch, original], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_original = apply_augmentation(sketch, original)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_original)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, original = load_img(img_path)
    sketch, original = apply_augmentation(sketch, original)
    return sketch, original

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, original = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(original[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, original):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, original, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, original, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 500

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, original) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, original)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 20 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[20]
# Generator_loss:1.1909
# L1_loss:0.2797
# Discriminator_loss:1.3331
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.0858
# L1_loss:0.2295
# Discriminator_loss:0.9849
#
# EPOCH[1] - STEP[60]
# Generator_loss:2.0886
# L1_loss:0.2623
# Discriminator_loss:0.4596
#
# EPOCH[1] - STEP[80]
# Generator_loss:2.5612
# L1_loss:0.2658
# Discriminator_loss:0.6353
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.1222
# L1_loss:0.2688
# Discriminator_loss:0.7878
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.9676
# L1_loss:0.2503
# Discriminator_loss:0.5724
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.0144
# L1_loss:0.2107
# Discriminator_loss:0.6183
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.5709
# L1_loss:0.2712
# Discriminator_loss:1.7810
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.1254
# L1_loss:0.2360
# Discriminator_loss:0.6812
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.2470
# L1_loss:0.1848
# Discriminator_loss:1.0246
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.6641
# L1_loss:0.2309
# Discriminator_loss:0.6114
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.4687
# L1_loss:0.2271
# Discriminator_loss:0.5857
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.6320
# L1_loss:0.2268
# Discriminator_loss:0.3730
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.7154
# L1_loss:0.2011
# Discriminator_loss:0.7206
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.5661
# L1_loss:0.2290
# Discriminator_loss:0.4031
#
# EPOCH[2] - STEP[80]
# Generator_loss:3.0585
# L1_loss:0.1924
# Discriminator_loss:0.2674
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.8812
# L1_loss:0.2225
# Discriminator_loss:1.4308
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.7934
# L1_loss:0.1783
# Discriminator_loss:0.6990
#
# EPOCH[2] - STEP[140]
# Generator_loss:0.7026
# L1_loss:0.1910
# Discriminator_loss:1.0083
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.8880
# L1_loss:0.1925
# Discriminator_loss:0.3456
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.5028
# L1_loss:0.2549
# Discriminator_loss:0.6677
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.6757
# L1_loss:0.2486
# Discriminator_loss:0.4027
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.7225
# L1_loss:0.2146
# Discriminator_loss:1.0297
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.4395
# L1_loss:0.2299
# Discriminator_loss:0.5833
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.1089
# L1_loss:0.1909
# Discriminator_loss:0.8638
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.6185
# L1_loss:0.2346
# Discriminator_loss:0.6472
#
# EPOCH[3] - STEP[60]
# Generator_loss:0.5576
# L1_loss:0.2014
# Discriminator_loss:1.4995
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.0101
# L1_loss:0.1848
# Discriminator_loss:0.3566
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.9713
# L1_loss:0.1752
# Discriminator_loss:0.4992
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.6408
# L1_loss:0.2146
# Discriminator_loss:0.4346
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.8243
# L1_loss:0.1932
# Discriminator_loss:1.4023
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.3636
# L1_loss:0.1784
# Discriminator_loss:0.6793
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.2524
# L1_loss:0.2375
# Discriminator_loss:1.7737
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.2798
# L1_loss:0.1998
# Discriminator_loss:0.8815
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.9395
# L1_loss:0.2235
# Discriminator_loss:1.6044
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.5424
# L1_loss:0.1739
# Discriminator_loss:1.0235
#
# EPOCH[4] - STEP[20]
# Generator_loss:0.4019
# L1_loss:0.2523
# Discriminator_loss:1.3902
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.1298
# L1_loss:0.2232
# Discriminator_loss:0.8138
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.8204
# L1_loss:0.2119
# Discriminator_loss:0.7861
#
# EPOCH[4] - STEP[80]
# Generator_loss:0.6266
# L1_loss:0.1744
# Discriminator_loss:1.0745
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.8486
# L1_loss:0.2321
# Discriminator_loss:0.5545
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.5829
# L1_loss:0.1694
# Discriminator_loss:1.0871
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.7076
# L1_loss:0.1743
# Discriminator_loss:1.7392
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.2191
# L1_loss:0.1951
# Discriminator_loss:0.6257
#
# EPOCH[4] - STEP[180]
# Generator_loss:0.9810
# L1_loss:0.1969
# Discriminator_loss:0.8621
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6840
# L1_loss:0.1948
# Discriminator_loss:0.5879
#
# EPOCH[4] - STEP[220]
# Generator_loss:0.5937
# L1_loss:0.2201
# Discriminator_loss:1.3862
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.6097
# L1_loss:0.1714
# Discriminator_loss:0.6479
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.3784
# L1_loss:0.2275
# Discriminator_loss:0.5712
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.0013
# L1_loss:0.1921
# Discriminator_loss:0.7565
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.3062
# L1_loss:0.1600
# Discriminator_loss:1.0331
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.4203
# L1_loss:0.2615
# Discriminator_loss:0.5395
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.0992
# L1_loss:0.2007
# Discriminator_loss:0.6996
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.2548
# L1_loss:0.2327
# Discriminator_loss:0.6030
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.7570
# L1_loss:0.2022
# Discriminator_loss:0.5194
#
# EPOCH[5] - STEP[160]
# Generator_loss:2.4386
# L1_loss:0.2160
# Discriminator_loss:0.2009
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.3715
# L1_loss:0.1847
# Discriminator_loss:0.5602
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.6025
# L1_loss:0.2132
# Discriminator_loss:0.6460
#
# EPOCH[5] - STEP[220]
# Generator_loss:1.0029
# L1_loss:0.1374
# Discriminator_loss:1.0044
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.3579
# L1_loss:0.1990
# Discriminator_loss:0.5514
#
# EPOCH[6] - STEP[20]
# Generator_loss:3.3625
# L1_loss:0.1474
# Discriminator_loss:1.7891
#
# EPOCH[6] - STEP[40]
# Generator_loss:2.4890
# L1_loss:0.1946
# Discriminator_loss:0.5604
#
# EPOCH[6] - STEP[60]
# Generator_loss:0.3529
# L1_loss:0.1975
# Discriminator_loss:1.6009
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.4015
# L1_loss:0.1732
# Discriminator_loss:0.5179
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.7962
# L1_loss:0.1789
# Discriminator_loss:0.5819
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.4152
# L1_loss:0.1843
# Discriminator_loss:1.0638
#
# EPOCH[6] - STEP[140]
# Generator_loss:2.1887
# L1_loss:0.1692
# Discriminator_loss:0.6565
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.1180
# L1_loss:0.1677
# Discriminator_loss:0.6480
#
# EPOCH[6] - STEP[180]
# Generator_loss:0.6257
# L1_loss:0.1643
# Discriminator_loss:1.2455
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.6663
# L1_loss:0.1837
# Discriminator_loss:0.2339
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.0030
# L1_loss:0.1461
# Discriminator_loss:0.9335
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.7093
# L1_loss:0.1842
# Discriminator_loss:1.0801
#
# EPOCH[7] - STEP[20]
# Generator_loss:0.9408
# L1_loss:0.1836
# Discriminator_loss:0.6902
#
# EPOCH[7] - STEP[40]
# Generator_loss:0.9956
# L1_loss:0.2317
# Discriminator_loss:1.2672
#
# EPOCH[7] - STEP[60]
# Generator_loss:1.6047
# L1_loss:0.2064
# Discriminator_loss:0.5338
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.4672
# L1_loss:0.2113
# Discriminator_loss:0.5002
#
# EPOCH[7] - STEP[100]
# Generator_loss:0.8168
# L1_loss:0.2136
# Discriminator_loss:0.8700
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.7616
# L1_loss:0.1699
# Discriminator_loss:0.6446
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.1646
# L1_loss:0.1819
# Discriminator_loss:0.9658
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.9219
# L1_loss:0.2046
# Discriminator_loss:0.8634
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.7587
# L1_loss:0.1937
# Discriminator_loss:0.4535
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.5033
# L1_loss:0.1833
# Discriminator_loss:1.4062
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.7473
# L1_loss:0.1877
# Discriminator_loss:0.7232
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.3007
# L1_loss:0.1606
# Discriminator_loss:0.8210
#
# EPOCH[8] - STEP[20]
# Generator_loss:0.9700
# L1_loss:0.1641
# Discriminator_loss:0.7583
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.0374
# L1_loss:0.1944
# Discriminator_loss:0.9039
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.2781
# L1_loss:0.1744
# Discriminator_loss:1.0159
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.8041
# L1_loss:0.1408
# Discriminator_loss:1.2623
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.2448
# L1_loss:0.1631
# Discriminator_loss:0.6468
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.8948
# L1_loss:0.1782
# Discriminator_loss:1.0716
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.5141
# L1_loss:0.1537
# Discriminator_loss:0.6038
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.7771
# L1_loss:0.2120
# Discriminator_loss:0.8620
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.1378
# L1_loss:0.1865
# Discriminator_loss:0.7517
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.9056
# L1_loss:0.2059
# Discriminator_loss:0.7443
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.7833
# L1_loss:0.1905
# Discriminator_loss:0.5032
#
# EPOCH[8] - STEP[240]
# Generator_loss:0.9194
# L1_loss:0.1966
# Discriminator_loss:0.7970
#
# EPOCH[9] - STEP[20]
# Generator_loss:3.0014
# L1_loss:0.2175
# Discriminator_loss:1.0509
#
# EPOCH[9] - STEP[40]
# Generator_loss:0.7768
# L1_loss:0.1838
# Discriminator_loss:0.8862
#
# EPOCH[9] - STEP[60]
# Generator_loss:2.0929
# L1_loss:0.1875
# Discriminator_loss:0.3955
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.6763
# L1_loss:0.1835
# Discriminator_loss:0.3718
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.7857
# L1_loss:0.1804
# Discriminator_loss:0.6785
#
# EPOCH[9] - STEP[120]
# Generator_loss:0.5305
# L1_loss:0.1838
# Discriminator_loss:1.0903
#
# EPOCH[9] - STEP[140]
# Generator_loss:2.0049
# L1_loss:0.2187
# Discriminator_loss:0.3271
#
# EPOCH[9] - STEP[160]
# Generator_loss:0.3780
# L1_loss:0.1686
# Discriminator_loss:1.7317
#
# EPOCH[9] - STEP[180]
# Generator_loss:3.3550
# L1_loss:0.1935
# Discriminator_loss:0.7844
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.3466
# L1_loss:0.1709
# Discriminator_loss:0.5679
#
# EPOCH[9] - STEP[220]
# Generator_loss:0.5508
# L1_loss:0.1649
# Discriminator_loss:1.1423
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.6318
# L1_loss:0.1809
# Discriminator_loss:0.7920
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.4139
# L1_loss:0.1654
# Discriminator_loss:0.7909
#
# EPOCH[10] - STEP[40]
# Generator_loss:0.7659
# L1_loss:0.1670
# Discriminator_loss:0.8232
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.1079
# L1_loss:0.1907
# Discriminator_loss:0.6916
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.7770
# L1_loss:0.2116
# Discriminator_loss:0.3075
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.5512
# L1_loss:0.1739
# Discriminator_loss:1.2396
#
# EPOCH[10] - STEP[120]
# Generator_loss:0.8737
# L1_loss:0.1911
# Discriminator_loss:0.8606
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.5503
# L1_loss:0.2002
# Discriminator_loss:0.5019
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.5119
# L1_loss:0.2549
# Discriminator_loss:0.5147
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.2959
# L1_loss:0.1697
# Discriminator_loss:0.5535
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.0510
# L1_loss:0.1677
# Discriminator_loss:0.4705
#
# EPOCH[10] - STEP[220]
# Generator_loss:2.3263
# L1_loss:0.1734
# Discriminator_loss:0.4755
#
# EPOCH[10] - STEP[240]
# Generator_loss:0.4984
# L1_loss:0.1656
# Discriminator_loss:1.1651
#
# EPOCH[11] - STEP[20]
# Generator_loss:2.6975
# L1_loss:0.1706
# Discriminator_loss:0.3862
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.7529
# L1_loss:0.1918
# Discriminator_loss:0.5722
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.3464
# L1_loss:0.1762
# Discriminator_loss:0.6263
#
# EPOCH[11] - STEP[80]
# Generator_loss:0.3016
# L1_loss:0.2586
# Discriminator_loss:1.5505
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.4648
# L1_loss:0.1726
# Discriminator_loss:1.4588
#
# EPOCH[11] - STEP[120]
# Generator_loss:0.5868
# L1_loss:0.1574
# Discriminator_loss:1.2005
#
# EPOCH[11] - STEP[140]
# Generator_loss:2.0101
# L1_loss:0.1505
# Discriminator_loss:1.9180
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.6598
# L1_loss:0.1694
# Discriminator_loss:0.3994
#
# EPOCH[11] - STEP[180]
# Generator_loss:2.1151
# L1_loss:0.1539
# Discriminator_loss:0.4660
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.4390
# L1_loss:0.1715
# Discriminator_loss:0.5034
#
# EPOCH[11] - STEP[220]
# Generator_loss:1.8065
# L1_loss:0.2230
# Discriminator_loss:0.3172
#
# EPOCH[11] - STEP[240]
# Generator_loss:2.4668
# L1_loss:0.1628
# Discriminator_loss:0.8211
#
# EPOCH[12] - STEP[20]
# Generator_loss:0.7728
# L1_loss:0.1323
# Discriminator_loss:0.9496
#
# EPOCH[12] - STEP[40]
# Generator_loss:0.7185
# L1_loss:0.2024
# Discriminator_loss:1.0115
#
# EPOCH[12] - STEP[60]
# Generator_loss:1.2033
# L1_loss:0.1508
# Discriminator_loss:0.5834
#
# EPOCH[12] - STEP[80]
# Generator_loss:2.5839
# L1_loss:0.1793
# Discriminator_loss:0.6514
#
# EPOCH[12] - STEP[100]
# Generator_loss:2.9850
# L1_loss:0.1849
# Discriminator_loss:0.3617
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.5717
# L1_loss:0.1845
# Discriminator_loss:0.4160
#
# EPOCH[12] - STEP[140]
# Generator_loss:2.0290
# L1_loss:0.1694
# Discriminator_loss:0.6938
#
# EPOCH[12] - STEP[160]
# Generator_loss:2.4288
# L1_loss:0.1817
# Discriminator_loss:0.2989
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.4524
# L1_loss:0.1707
# Discriminator_loss:0.9491
#
# EPOCH[12] - STEP[200]
# Generator_loss:0.7483
# L1_loss:0.1853
# Discriminator_loss:0.9321
#
# EPOCH[12] - STEP[220]
# Generator_loss:1.9107
# L1_loss:0.1567
# Discriminator_loss:1.0406
#
# EPOCH[12] - STEP[240]
# Generator_loss:2.4905
# L1_loss:0.1653
# Discriminator_loss:0.2695
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.2237
# L1_loss:0.1713
# Discriminator_loss:0.2551
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.3615
# L1_loss:0.1753
# Discriminator_loss:1.1884
#
# EPOCH[13] - STEP[60]
# Generator_loss:0.0934
# L1_loss:0.1900
# Discriminator_loss:2.8535
#
# EPOCH[13] - STEP[80]
# Generator_loss:1.6863
# L1_loss:0.2129
# Discriminator_loss:0.4345
#
# EPOCH[13] - STEP[100]
# Generator_loss:1.0084
# L1_loss:0.1952
# Discriminator_loss:0.8985
#
# EPOCH[13] - STEP[120]
# Generator_loss:2.5824
# L1_loss:0.1488
# Discriminator_loss:0.5082
#
# EPOCH[13] - STEP[140]
# Generator_loss:1.1643
# L1_loss:0.1986
# Discriminator_loss:0.7535
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.1647
# L1_loss:0.1884
# Discriminator_loss:0.8903
#
# EPOCH[13] - STEP[180]
# Generator_loss:3.3770
# L1_loss:0.1670
# Discriminator_loss:0.7079
#
# EPOCH[13] - STEP[200]
# Generator_loss:3.0204
# L1_loss:0.1726
# Discriminator_loss:0.7638
#
# EPOCH[13] - STEP[220]
# Generator_loss:3.2660
# L1_loss:0.1654
# Discriminator_loss:0.8997
#
# EPOCH[13] - STEP[240]
# Generator_loss:0.9091
# L1_loss:0.1989
# Discriminator_loss:1.1328
#
# EPOCH[14] - STEP[20]
# Generator_loss:0.4185
# L1_loss:0.1703
# Discriminator_loss:1.3135
#
# EPOCH[14] - STEP[40]
# Generator_loss:1.6804
# L1_loss:0.1378
# Discriminator_loss:0.4924
#
# EPOCH[14] - STEP[60]
# Generator_loss:1.3740
# L1_loss:0.2172
# Discriminator_loss:0.5270
#
# EPOCH[14] - STEP[80]
# Generator_loss:1.2422
# L1_loss:0.1463
# Discriminator_loss:0.8725
#
# EPOCH[14] - STEP[100]
# Generator_loss:1.6021
# L1_loss:0.2120
# Discriminator_loss:0.3762
#
# EPOCH[14] - STEP[120]
# Generator_loss:2.5193
# L1_loss:0.1372
# Discriminator_loss:1.1596
#
# EPOCH[14] - STEP[140]
# Generator_loss:1.2523
# L1_loss:0.1759
# Discriminator_loss:0.7330
#
# EPOCH[14] - STEP[160]
# Generator_loss:1.4199
# L1_loss:0.1638
# Discriminator_loss:0.4852
#
# EPOCH[14] - STEP[180]
# Generator_loss:1.8905
# L1_loss:0.1644
# Discriminator_loss:0.4734
#
# EPOCH[14] - STEP[200]
# Generator_loss:1.5211
# L1_loss:0.1852
# Discriminator_loss:0.3623
#
# EPOCH[14] - STEP[220]
# Generator_loss:0.7141
# L1_loss:0.1745
# Discriminator_loss:1.6544
#
# EPOCH[14] - STEP[240]
# Generator_loss:0.5604
# L1_loss:0.1780
# Discriminator_loss:1.1198
#
# EPOCH[15] - STEP[20]
# Generator_loss:1.2933
# L1_loss:0.1555
# Discriminator_loss:0.7462
#
# EPOCH[15] - STEP[40]
# Generator_loss:2.8147
# L1_loss:0.2031
# Discriminator_loss:0.7607
#
# EPOCH[15] - STEP[60]
# Generator_loss:3.0114
# L1_loss:0.1852
# Discriminator_loss:0.1263
#
# EPOCH[15] - STEP[80]
# Generator_loss:0.3422
# L1_loss:0.2121
# Discriminator_loss:1.6962
#
# EPOCH[15] - STEP[100]
# Generator_loss:1.2248
# L1_loss:0.1863
# Discriminator_loss:0.5083
#
# EPOCH[15] - STEP[120]
# Generator_loss:0.8552
# L1_loss:0.1831
# Discriminator_loss:0.8330
#
# EPOCH[15] - STEP[140]
# Generator_loss:3.3162
# L1_loss:0.1724
# Discriminator_loss:0.7083
#
# EPOCH[15] - STEP[160]
# Generator_loss:1.0710
# L1_loss:0.1447
# Discriminator_loss:1.0225
#
# EPOCH[15] - STEP[180]
# Generator_loss:1.8897
# L1_loss:0.1558
# Discriminator_loss:0.4477
#
# EPOCH[15] - STEP[200]
# Generator_loss:2.0082
# L1_loss:0.1416
# Discriminator_loss:1.1100
#
# EPOCH[15] - STEP[220]
# Generator_loss:3.7445
# L1_loss:0.1777
# Discriminator_loss:0.8667
#
# EPOCH[15] - STEP[240]
# Generator_loss:1.6224
# L1_loss:0.1822
# Discriminator_loss:0.7902
#
# EPOCH[16] - STEP[20]
# Generator_loss:0.9474
# L1_loss:0.1551
# Discriminator_loss:0.7137
#
# EPOCH[16] - STEP[40]
# Generator_loss:2.0683
# L1_loss:0.1537
# Discriminator_loss:0.5840
#
# EPOCH[16] - STEP[60]
# Generator_loss:2.1752
# L1_loss:0.1600
# Discriminator_loss:0.5469
#
# EPOCH[16] - STEP[80]
# Generator_loss:1.8076
# L1_loss:0.1589
# Discriminator_loss:0.3094
#
# EPOCH[16] - STEP[100]
# Generator_loss:0.9487
# L1_loss:0.1505
# Discriminator_loss:1.0750
#
# EPOCH[16] - STEP[120]
# Generator_loss:2.2772
# L1_loss:0.1735
# Discriminator_loss:0.4004
#
# EPOCH[16] - STEP[140]
# Generator_loss:2.3654
# L1_loss:0.1327
# Discriminator_loss:0.6335
#
# EPOCH[16] - STEP[160]
# Generator_loss:1.0564
# L1_loss:0.2074
# Discriminator_loss:0.6305
#
# EPOCH[16] - STEP[180]
# Generator_loss:1.0530
# L1_loss:0.1789
# Discriminator_loss:0.7173
#
# EPOCH[16] - STEP[200]
# Generator_loss:3.4920
# L1_loss:0.1489
# Discriminator_loss:0.6397
#
# EPOCH[16] - STEP[220]
# Generator_loss:1.8943
# L1_loss:0.1737
# Discriminator_loss:0.3505
#
# EPOCH[16] - STEP[240]
# Generator_loss:2.3496
# L1_loss:0.1923
# Discriminator_loss:0.4161
#
# EPOCH[17] - STEP[20]
# Generator_loss:1.1654
# L1_loss:0.1431
# Discriminator_loss:0.5563
#
# EPOCH[17] - STEP[40]
# Generator_loss:0.8517
# L1_loss:0.1799
# Discriminator_loss:0.7968
#
# EPOCH[17] - STEP[60]
# Generator_loss:0.5119
# L1_loss:0.1430
# Discriminator_loss:1.3739
#
# EPOCH[17] - STEP[80]
# Generator_loss:1.1198
# L1_loss:0.1477
# Discriminator_loss:0.8248
#
# EPOCH[17] - STEP[100]
# Generator_loss:1.3035
# L1_loss:0.2394
# Discriminator_loss:0.6220
#
# EPOCH[17] - STEP[120]
# Generator_loss:1.4123
# L1_loss:0.1735
# Discriminator_loss:0.4368
#
# EPOCH[17] - STEP[140]
# Generator_loss:1.4728
# L1_loss:0.1591
# Discriminator_loss:0.3978
#
# EPOCH[17] - STEP[160]
# Generator_loss:2.4733
# L1_loss:0.1535
# Discriminator_loss:0.3494
#
# EPOCH[17] - STEP[180]
# Generator_loss:2.3569
# L1_loss:0.1367
# Discriminator_loss:0.7354
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.9787
# L1_loss:0.1523
# Discriminator_loss:0.5605
#
# EPOCH[17] - STEP[220]
# Generator_loss:2.7339
# L1_loss:0.1474
# Discriminator_loss:1.0602
#
# EPOCH[17] - STEP[240]
# Generator_loss:0.5696
# L1_loss:0.1800
# Discriminator_loss:1.5457
#
# EPOCH[18] - STEP[20]
# Generator_loss:1.6198
# L1_loss:0.1572
# Discriminator_loss:0.4419
#
# EPOCH[18] - STEP[40]
# Generator_loss:1.6535
# L1_loss:0.1678
# Discriminator_loss:0.5362
#
# EPOCH[18] - STEP[60]
# Generator_loss:1.8914
# L1_loss:0.1732
# Discriminator_loss:0.4734
#
# EPOCH[18] - STEP[80]
# Generator_loss:2.6071
# L1_loss:0.1502
# Discriminator_loss:1.2566
#
# EPOCH[18] - STEP[100]
# Generator_loss:0.7264
# L1_loss:0.1739
# Discriminator_loss:0.9331
#
# EPOCH[18] - STEP[120]
# Generator_loss:0.9350
# L1_loss:0.1658
# Discriminator_loss:0.8689
#
# EPOCH[18] - STEP[140]
# Generator_loss:0.3195
# L1_loss:0.1906
# Discriminator_loss:1.5785
#
# EPOCH[18] - STEP[160]
# Generator_loss:2.9573
# L1_loss:0.1652
# Discriminator_loss:0.7334
#
# EPOCH[18] - STEP[180]
# Generator_loss:1.6331
# L1_loss:0.1598
# Discriminator_loss:0.9426
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.4979
# L1_loss:0.1436
# Discriminator_loss:0.5468
#
# EPOCH[18] - STEP[220]
# Generator_loss:2.7922
# L1_loss:0.1708
# Discriminator_loss:0.6147
#
# EPOCH[18] - STEP[240]
# Generator_loss:0.7140
# L1_loss:0.2051
# Discriminator_loss:0.9954
#
# EPOCH[19] - STEP[20]
# Generator_loss:1.2057
# L1_loss:0.1351
# Discriminator_loss:0.7084
#
# EPOCH[19] - STEP[40]
# Generator_loss:2.0216
# L1_loss:0.1591
# Discriminator_loss:0.3800
#
# EPOCH[19] - STEP[60]
# Generator_loss:1.7326
# L1_loss:0.1907
# Discriminator_loss:0.3086
#
# EPOCH[19] - STEP[80]
# Generator_loss:1.7287
# L1_loss:0.1601
# Discriminator_loss:0.3252
#
# EPOCH[19] - STEP[100]
# Generator_loss:2.1227
# L1_loss:0.1734
# Discriminator_loss:0.2492
#
# EPOCH[19] - STEP[120]
# Generator_loss:1.6478
# L1_loss:0.1859
# Discriminator_loss:0.3464
#
# EPOCH[19] - STEP[140]
# Generator_loss:3.4569
# L1_loss:0.1382
# Discriminator_loss:0.8477
#
# EPOCH[19] - STEP[160]
# Generator_loss:0.4563
# L1_loss:0.1561
# Discriminator_loss:1.4006
#
# EPOCH[19] - STEP[180]
# Generator_loss:0.9607
# L1_loss:0.1362
# Discriminator_loss:0.6491
#
# EPOCH[19] - STEP[200]
# Generator_loss:1.8083
# L1_loss:0.1735
# Discriminator_loss:0.7839
#
# EPOCH[19] - STEP[220]
# Generator_loss:0.9392
# L1_loss:0.2062
# Discriminator_loss:0.8324
#
# EPOCH[19] - STEP[240]
# Generator_loss:2.0022
# L1_loss:0.1966
# Discriminator_loss:0.4193
#
# EPOCH[20] - STEP[20]
# Generator_loss:1.9371
# L1_loss:0.1887
# Discriminator_loss:0.3242
#
# EPOCH[20] - STEP[40]
# Generator_loss:2.9371
# L1_loss:0.1483
# Discriminator_loss:0.7042
#
# EPOCH[20] - STEP[60]
# Generator_loss:0.6875
# L1_loss:0.1721
# Discriminator_loss:0.9476
#
# EPOCH[20] - STEP[80]
# Generator_loss:0.4462
# L1_loss:0.1974
# Discriminator_loss:1.3934
#
# EPOCH[20] - STEP[100]
# Generator_loss:2.4308
# L1_loss:0.1339
# Discriminator_loss:0.5833
#
# EPOCH[20] - STEP[120]
# Generator_loss:2.1876
# L1_loss:0.1653
# Discriminator_loss:0.9708
#
# EPOCH[20] - STEP[140]
# Generator_loss:2.3031
# L1_loss:0.1472
# Discriminator_loss:0.2770
#
# EPOCH[20] - STEP[160]
# Generator_loss:1.5920
# L1_loss:0.1600
# Discriminator_loss:0.7142
#
# EPOCH[20] - STEP[180]
# Generator_loss:0.6615
# L1_loss:0.1681
# Discriminator_loss:0.9205
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.5065
# L1_loss:0.1408
# Discriminator_loss:0.5328
#
# EPOCH[20] - STEP[220]
# Generator_loss:3.5391
# L1_loss:0.1739
# Discriminator_loss:0.8857
#
# EPOCH[20] - STEP[240]
# Generator_loss:1.2335
# L1_loss:0.1420
# Discriminator_loss:0.6956
#
# EPOCH[21] - STEP[20]
# Generator_loss:1.4362
# L1_loss:0.1273
# Discriminator_loss:0.6833
#
# EPOCH[21] - STEP[40]
# Generator_loss:2.8911
# L1_loss:0.1995
# Discriminator_loss:0.4119
#
# EPOCH[21] - STEP[60]
# Generator_loss:0.5171
# L1_loss:0.1923
# Discriminator_loss:1.2814
#
# EPOCH[21] - STEP[80]
# Generator_loss:1.1954
# L1_loss:0.1361
# Discriminator_loss:1.1314
#
# EPOCH[21] - STEP[100]
# Generator_loss:2.4226
# L1_loss:0.1424
# Discriminator_loss:0.9762
#
# EPOCH[21] - STEP[120]
# Generator_loss:2.8562
# L1_loss:0.1802
# Discriminator_loss:1.5926
#
# EPOCH[21] - STEP[140]
# Generator_loss:3.0015
# L1_loss:0.1670
# Discriminator_loss:0.5157
#
# EPOCH[21] - STEP[160]
# Generator_loss:0.5415
# L1_loss:0.1492
# Discriminator_loss:1.5392
#
# EPOCH[21] - STEP[180]
# Generator_loss:1.9211
# L1_loss:0.1646
# Discriminator_loss:0.3599
#
# EPOCH[21] - STEP[200]
# Generator_loss:1.2060
# L1_loss:0.1676
# Discriminator_loss:0.5854
#
# EPOCH[21] - STEP[220]
# Generator_loss:1.7586
# L1_loss:0.1468
# Discriminator_loss:0.5913
#
# EPOCH[21] - STEP[240]
# Generator_loss:3.6982
# L1_loss:0.1744
# Discriminator_loss:2.1980
#
# EPOCH[22] - STEP[20]
# Generator_loss:2.2184
# L1_loss:0.1480
# Discriminator_loss:0.3976
#
# EPOCH[22] - STEP[40]
# Generator_loss:0.4527
# L1_loss:0.1353
# Discriminator_loss:1.8606
#
# EPOCH[22] - STEP[60]
# Generator_loss:1.2748
# L1_loss:0.1585
# Discriminator_loss:0.4929
#
# EPOCH[22] - STEP[80]
# Generator_loss:0.8926
# L1_loss:0.1414
# Discriminator_loss:0.9406
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.3160
# L1_loss:0.1870
# Discriminator_loss:0.5418
#
# EPOCH[22] - STEP[120]
# Generator_loss:0.9941
# L1_loss:0.2095
# Discriminator_loss:0.7508
#
# EPOCH[22] - STEP[140]
# Generator_loss:0.8459
# L1_loss:0.1386
# Discriminator_loss:0.8268
#
# EPOCH[22] - STEP[160]
# Generator_loss:2.5630
# L1_loss:0.1756
# Discriminator_loss:0.3075
#
# EPOCH[22] - STEP[180]
# Generator_loss:0.8673
# L1_loss:0.1501
# Discriminator_loss:1.0052
#
# EPOCH[22] - STEP[200]
# Generator_loss:1.5244
# L1_loss:0.1507
# Discriminator_loss:0.4589
#
# EPOCH[22] - STEP[220]
# Generator_loss:0.7424
# L1_loss:0.1392
# Discriminator_loss:1.0044
#
# EPOCH[22] - STEP[240]
# Generator_loss:1.7738
# L1_loss:0.1397
# Discriminator_loss:0.4548
#
# EPOCH[23] - STEP[20]
# Generator_loss:2.1110
# L1_loss:0.1416
# Discriminator_loss:0.5225
#
# EPOCH[23] - STEP[40]
# Generator_loss:1.6860
# L1_loss:0.1889
# Discriminator_loss:0.6815
#
# EPOCH[23] - STEP[60]
# Generator_loss:2.7162
# L1_loss:0.1772
# Discriminator_loss:0.3034
#
# EPOCH[23] - STEP[80]
# Generator_loss:1.5307
# L1_loss:0.1823
# Discriminator_loss:1.0345
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.1719
# L1_loss:0.1501
# Discriminator_loss:0.8134
#
# EPOCH[23] - STEP[120]
# Generator_loss:3.0903
# L1_loss:0.1535
# Discriminator_loss:1.3561
#
# EPOCH[23] - STEP[140]
# Generator_loss:1.0801
# L1_loss:0.1721
# Discriminator_loss:0.7909
#
# EPOCH[23] - STEP[160]
# Generator_loss:1.3710
# L1_loss:0.1605
# Discriminator_loss:0.6069
#
# EPOCH[23] - STEP[180]
# Generator_loss:2.1111
# L1_loss:0.1355
# Discriminator_loss:0.8793
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.5247
# L1_loss:0.1451
# Discriminator_loss:1.3142
#
# EPOCH[23] - STEP[220]
# Generator_loss:1.7593
# L1_loss:0.1753
# Discriminator_loss:0.5937
#
# EPOCH[23] - STEP[240]
# Generator_loss:2.6930
# L1_loss:0.1641
# Discriminator_loss:0.2919
#
# EPOCH[24] - STEP[20]
# Generator_loss:1.4893
# L1_loss:0.1316
# Discriminator_loss:1.3237
#
# EPOCH[24] - STEP[40]
# Generator_loss:1.9296
# L1_loss:0.1527
# Discriminator_loss:0.5943
#
# EPOCH[24] - STEP[60]
# Generator_loss:1.2311
# L1_loss:0.1531
# Discriminator_loss:0.9276
#
# EPOCH[24] - STEP[80]
# Generator_loss:2.7887
# L1_loss:0.1579
# Discriminator_loss:0.2598
#
# EPOCH[24] - STEP[100]
# Generator_loss:2.5556
# L1_loss:0.1514
# Discriminator_loss:0.6537
#
# EPOCH[24] - STEP[120]
# Generator_loss:2.4994
# L1_loss:0.1258
# Discriminator_loss:1.2652
#
# EPOCH[24] - STEP[140]
# Generator_loss:2.1598
# L1_loss:0.1380
# Discriminator_loss:0.7765
#
# EPOCH[24] - STEP[160]
# Generator_loss:1.7395
# L1_loss:0.1588
# Discriminator_loss:0.6527
#
# EPOCH[24] - STEP[180]
# Generator_loss:1.0174
# L1_loss:0.1373
# Discriminator_loss:0.7762
#
# EPOCH[24] - STEP[200]
# Generator_loss:2.7400
# L1_loss:0.1585
# Discriminator_loss:0.8088
#
# EPOCH[24] - STEP[220]
# Generator_loss:2.2999
# L1_loss:0.1364
# Discriminator_loss:0.8940
#
# EPOCH[24] - STEP[240]
# Generator_loss:2.5102
# L1_loss:0.1328
# Discriminator_loss:0.6325
#
# EPOCH[25] - STEP[20]
# Generator_loss:2.6502
# L1_loss:0.1756
# Discriminator_loss:0.3323
#
# EPOCH[25] - STEP[40]
# Generator_loss:2.9209
# L1_loss:0.1779
# Discriminator_loss:0.4299
#
# EPOCH[25] - STEP[60]
# Generator_loss:3.3276
# L1_loss:0.1661
# Discriminator_loss:1.3445
#
# EPOCH[25] - STEP[80]
# Generator_loss:2.0199
# L1_loss:0.1775
# Discriminator_loss:0.2347
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.1214
# L1_loss:0.1967
# Discriminator_loss:0.3505
#
# EPOCH[25] - STEP[120]
# Generator_loss:1.4011
# L1_loss:0.1297
# Discriminator_loss:0.6050
#
# EPOCH[25] - STEP[140]
# Generator_loss:1.9039
# L1_loss:0.1449
# Discriminator_loss:0.7324
#
# EPOCH[25] - STEP[160]
# Generator_loss:3.9847
# L1_loss:0.1702
# Discriminator_loss:1.4163
#
# EPOCH[25] - STEP[180]
# Generator_loss:0.5109
# L1_loss:0.1482
# Discriminator_loss:1.5063
#
# EPOCH[25] - STEP[200]
# Generator_loss:3.1086
# L1_loss:0.1610
# Discriminator_loss:0.5019
#
# EPOCH[25] - STEP[220]
# Generator_loss:2.7256
# L1_loss:0.1602
# Discriminator_loss:0.2237
#
# EPOCH[25] - STEP[240]
# Generator_loss:2.2611
# L1_loss:0.1441
# Discriminator_loss:0.6420
#
# EPOCH[26] - STEP[20]
# Generator_loss:2.7886
# L1_loss:0.1640
# Discriminator_loss:0.3338
#
# EPOCH[26] - STEP[40]
# Generator_loss:1.2572
# L1_loss:0.1763
# Discriminator_loss:0.5270
#
# EPOCH[26] - STEP[60]
# Generator_loss:3.4465
# L1_loss:0.1692
# Discriminator_loss:0.9998
#
# EPOCH[26] - STEP[80]
# Generator_loss:2.2443
# L1_loss:0.1391
# Discriminator_loss:0.8684
#
# EPOCH[26] - STEP[100]
# Generator_loss:2.2037
# L1_loss:0.1506
# Discriminator_loss:0.3811
#
# EPOCH[26] - STEP[120]
# Generator_loss:2.2321
# L1_loss:0.1376
# Discriminator_loss:1.5352
#
# EPOCH[26] - STEP[140]
# Generator_loss:0.7320
# L1_loss:0.1493
# Discriminator_loss:1.0197
#
# EPOCH[26] - STEP[160]
# Generator_loss:1.9513
# L1_loss:0.1220
# Discriminator_loss:1.0595
#
# EPOCH[26] - STEP[180]
# Generator_loss:1.6233
# L1_loss:0.1301
# Discriminator_loss:0.4357
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.1649
# L1_loss:0.1596
# Discriminator_loss:0.3184
#
# EPOCH[26] - STEP[220]
# Generator_loss:1.7477
# L1_loss:0.1389
# Discriminator_loss:0.3456
#
# EPOCH[26] - STEP[240]
# Generator_loss:2.5441
# L1_loss:0.1811
# Discriminator_loss:0.2111
#
# EPOCH[27] - STEP[20]
# Generator_loss:1.2509
# L1_loss:0.1480
# Discriminator_loss:0.5643
#
# EPOCH[27] - STEP[40]
# Generator_loss:2.9423
# L1_loss:0.1416
# Discriminator_loss:0.5004
#
# EPOCH[27] - STEP[60]
# Generator_loss:2.2664
# L1_loss:0.1765
# Discriminator_loss:0.2298
#
# EPOCH[27] - STEP[80]
# Generator_loss:3.2922
# L1_loss:0.1482
# Discriminator_loss:0.7619
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.8359
# L1_loss:0.1665
# Discriminator_loss:0.3515
#
# EPOCH[27] - STEP[120]
# Generator_loss:2.4966
# L1_loss:0.1264
# Discriminator_loss:1.7646
#
# EPOCH[27] - STEP[140]
# Generator_loss:3.7386
# L1_loss:0.1336
# Discriminator_loss:0.6809
#
# EPOCH[27] - STEP[160]
# Generator_loss:1.6851
# L1_loss:0.1556
# Discriminator_loss:0.4529
#
# EPOCH[27] - STEP[180]
# Generator_loss:3.3537
# L1_loss:0.1721
# Discriminator_loss:0.2818
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.2096
# L1_loss:0.1447
# Discriminator_loss:0.6206
#
# EPOCH[27] - STEP[220]
# Generator_loss:3.6052
# L1_loss:0.1339
# Discriminator_loss:1.2974
#
# EPOCH[27] - STEP[240]
# Generator_loss:1.7424
# ...
# Generator_loss:4.5689
# L1_loss:0.0979
# Discriminator_loss:0.2193
#
# EPOCH[492] - STEP[60]
# Generator_loss:7.5895
# L1_loss:0.1187
# Discriminator_loss:0.0394
#
# EPOCH[492] - STEP[80]
# Generator_loss:5.4332
# L1_loss:0.1068
# Discriminator_loss:0.0308
#
# EPOCH[492] - STEP[100]
# Generator_loss:7.5952
# L1_loss:0.1017
# Discriminator_loss:0.0185
#
# EPOCH[492] - STEP[120]
# Generator_loss:3.2877
# L1_loss:0.1095
# Discriminator_loss:0.1475
#
# EPOCH[492] - STEP[140]
# Generator_loss:5.4648
# L1_loss:0.1164
# Discriminator_loss:0.0118
#
# EPOCH[492] - STEP[160]
# Generator_loss:7.1915
# L1_loss:0.1013
# Discriminator_loss:0.0045
#
# EPOCH[492] - STEP[180]
# Generator_loss:1.0422
# L1_loss:0.1256
# Discriminator_loss:0.9612
#
# EPOCH[492] - STEP[200]
# Generator_loss:1.2618
# L1_loss:0.0851
# Discriminator_loss:0.8264
#
# EPOCH[492] - STEP[220]
# Generator_loss:4.0579
# L1_loss:0.0983
# Discriminator_loss:0.0568
#
# EPOCH[492] - STEP[240]
# Generator_loss:4.6182
# L1_loss:0.1029
# Discriminator_loss:0.0537
#
# EPOCH[493] - STEP[20]
# Generator_loss:3.9557
# L1_loss:0.1248
# Discriminator_loss:0.0499
#
# EPOCH[493] - STEP[40]
# Generator_loss:1.6955
# L1_loss:0.1066
# Discriminator_loss:0.4550
#
# EPOCH[493] - STEP[60]
# Generator_loss:2.9459
# L1_loss:0.1115
# Discriminator_loss:0.1329
#
# EPOCH[493] - STEP[80]
# Generator_loss:3.0378
# L1_loss:0.1032
# Discriminator_loss:0.2197
#
# EPOCH[493] - STEP[100]
# Generator_loss:3.9137
# L1_loss:0.1064
# Discriminator_loss:1.3499
#
# EPOCH[493] - STEP[120]
# Generator_loss:6.9955
# L1_loss:0.1441
# Discriminator_loss:0.0615
#
# EPOCH[493] - STEP[140]
# Generator_loss:5.7234
# L1_loss:0.0948
# Discriminator_loss:0.0170
#
# EPOCH[493] - STEP[160]
# Generator_loss:7.1679
# L1_loss:0.1292
# Discriminator_loss:0.5450
#
# EPOCH[493] - STEP[180]
# Generator_loss:6.8554
# L1_loss:0.0962
# Discriminator_loss:0.0935
#
# EPOCH[493] - STEP[200]
# Generator_loss:4.7065
# L1_loss:0.0913
# Discriminator_loss:0.1295
#
# EPOCH[493] - STEP[220]
# Generator_loss:5.8298
# L1_loss:0.1116
# Discriminator_loss:0.0186
#
# EPOCH[493] - STEP[240]
# Generator_loss:1.8908
# L1_loss:0.1086
# Discriminator_loss:2.0516
#
# EPOCH[494] - STEP[20]
# Generator_loss:5.1636
# L1_loss:0.1036
# Discriminator_loss:0.0256
#
# EPOCH[494] - STEP[40]
# Generator_loss:3.5659
# L1_loss:0.0922
# Discriminator_loss:0.0764
#
# EPOCH[494] - STEP[60]
# Generator_loss:5.0710
# L1_loss:0.1130
# Discriminator_loss:0.0219
#
# EPOCH[494] - STEP[80]
# Generator_loss:6.3943
# L1_loss:0.1124
# Discriminator_loss:0.6842
#
# EPOCH[494] - STEP[100]
# Generator_loss:8.0983
# L1_loss:0.1293
# Discriminator_loss:0.0189
#
# EPOCH[494] - STEP[120]
# Generator_loss:4.1674
# L1_loss:0.1197
# Discriminator_loss:0.1989
#
# EPOCH[494] - STEP[140]
# Generator_loss:2.8718
# L1_loss:0.1034
# Discriminator_loss:0.6078
#
# EPOCH[494] - STEP[160]
# Generator_loss:3.4477
# L1_loss:0.1132
# Discriminator_loss:0.2818
#
# EPOCH[494] - STEP[180]
# Generator_loss:2.3828
# L1_loss:0.1159
# Discriminator_loss:0.2905
#
# EPOCH[494] - STEP[200]
# Generator_loss:7.0383
# L1_loss:0.1261
# Discriminator_loss:0.0029
#
# EPOCH[494] - STEP[220]
# Generator_loss:10.1772
# L1_loss:0.1317
# Discriminator_loss:0.0133
#
# EPOCH[494] - STEP[240]
# Generator_loss:4.7313
# L1_loss:0.1313
# Discriminator_loss:0.0833
#
# EPOCH[495] - STEP[20]
# Generator_loss:6.1509
# L1_loss:0.1302
# Discriminator_loss:0.0443
#
# EPOCH[495] - STEP[40]
# Generator_loss:5.3960
# L1_loss:0.1149
# Discriminator_loss:0.0236
#
# EPOCH[495] - STEP[60]
# Generator_loss:7.1409
# L1_loss:0.1246
# Discriminator_loss:0.0028
#
# EPOCH[495] - STEP[80]
# Generator_loss:6.7553
# L1_loss:0.0838
# Discriminator_loss:0.5982
#
# EPOCH[495] - STEP[100]
# Generator_loss:0.9223
# L1_loss:0.1093
# Discriminator_loss:0.8546
#
# EPOCH[495] - STEP[120]
# Generator_loss:5.3906
# L1_loss:0.1134
# Discriminator_loss:1.1452
#
# EPOCH[495] - STEP[140]
# Generator_loss:4.0910
# L1_loss:0.1016
# Discriminator_loss:0.0614
#
# EPOCH[495] - STEP[160]
# Generator_loss:5.0523
# L1_loss:0.1078
# Discriminator_loss:0.0240
#
# EPOCH[495] - STEP[180]
# Generator_loss:7.9809
# L1_loss:0.1030
# Discriminator_loss:0.1280
#
# EPOCH[495] - STEP[200]
# Generator_loss:4.5501
# L1_loss:0.1004
# Discriminator_loss:0.0415
#
# EPOCH[495] - STEP[220]
# Generator_loss:7.6566
# L1_loss:0.1337
# Discriminator_loss:0.0131
#
# EPOCH[495] - STEP[240]
# Generator_loss:3.6256
# L1_loss:0.1229
# Discriminator_loss:0.0631
#
# EPOCH[496] - STEP[20]
# Generator_loss:7.1359
# L1_loss:0.1060
# Discriminator_loss:0.0084
#
# EPOCH[496] - STEP[40]
# Generator_loss:5.5998
# L1_loss:0.0974
# Discriminator_loss:0.0973
#
# EPOCH[496] - STEP[60]
# Generator_loss:6.6053
# L1_loss:0.1134
# Discriminator_loss:0.0298
#
# EPOCH[496] - STEP[80]
# Generator_loss:2.9420
# L1_loss:0.0974
# Discriminator_loss:0.2306
#
# EPOCH[496] - STEP[100]
# Generator_loss:3.0952
# L1_loss:0.0917
# Discriminator_loss:0.1499
#
# EPOCH[496] - STEP[120]
# Generator_loss:5.1022
# L1_loss:0.0903
# Discriminator_loss:0.0940
#
# EPOCH[496] - STEP[140]
# Generator_loss:6.1506
# L1_loss:0.1078
# Discriminator_loss:0.0119
#
# EPOCH[496] - STEP[160]
# Generator_loss:2.1854
# L1_loss:0.1264
# Discriminator_loss:0.4267
#
# EPOCH[496] - STEP[180]
# Generator_loss:6.5457
# L1_loss:0.1323
# Discriminator_loss:0.1272
#
# EPOCH[496] - STEP[200]
# Generator_loss:3.2666
# L1_loss:0.1279
# Discriminator_loss:0.1091
#
# EPOCH[496] - STEP[220]
# Generator_loss:3.6268
# L1_loss:0.1420
# Discriminator_loss:0.0739
#
# EPOCH[496] - STEP[240]
# Generator_loss:7.5123
# L1_loss:0.1229
# Discriminator_loss:0.0052
#
# EPOCH[497] - STEP[20]
# Generator_loss:5.5873
# L1_loss:0.1188
# Discriminator_loss:0.0688
#
# EPOCH[497] - STEP[40]
# Generator_loss:9.2472
# L1_loss:0.1074
# Discriminator_loss:0.0054
#
# EPOCH[497] - STEP[60]
# Generator_loss:1.9763
# L1_loss:0.1238
# Discriminator_loss:0.4524
#
# EPOCH[497] - STEP[80]
# Generator_loss:4.3929
# L1_loss:0.1084
# Discriminator_loss:0.0656
#
# EPOCH[497] - STEP[100]
# Generator_loss:5.0265
# L1_loss:0.1064
# Discriminator_loss:0.0351
#
# EPOCH[497] - STEP[120]
# Generator_loss:5.4273
# L1_loss:0.0959
# Discriminator_loss:0.0301
#
# EPOCH[497] - STEP[140]
# Generator_loss:5.7033
# L1_loss:0.1036
# Discriminator_loss:0.0883
#
# EPOCH[497] - STEP[160]
# Generator_loss:4.1760
# L1_loss:0.1057
# Discriminator_loss:0.1658
#
# EPOCH[497] - STEP[180]
# Generator_loss:4.2688
# L1_loss:0.1045
# Discriminator_loss:0.1166
#
# EPOCH[497] - STEP[200]
# Generator_loss:5.9812
# L1_loss:0.1420
# Discriminator_loss:0.0102
#
# EPOCH[497] - STEP[220]
# Generator_loss:6.8781
# L1_loss:0.1196
# Discriminator_loss:0.0085
#
# EPOCH[497] - STEP[240]
# Generator_loss:4.8123
# L1_loss:0.1041
# Discriminator_loss:0.0336
#
# EPOCH[498] - STEP[20]
# Generator_loss:1.4414
# L1_loss:0.1056
# Discriminator_loss:0.5715
#
# EPOCH[498] - STEP[40]
# Generator_loss:5.3436
# L1_loss:0.1036
# Discriminator_loss:0.1228
#
# EPOCH[498] - STEP[60]
# Generator_loss:5.4701
# L1_loss:0.0945
# Discriminator_loss:0.1319
#
# EPOCH[498] - STEP[80]
# Generator_loss:2.5634
# L1_loss:0.1298
# Discriminator_loss:0.1976
#
# EPOCH[498] - STEP[100]
# Generator_loss:1.1231
# L1_loss:0.1411
# Discriminator_loss:0.8775
#
# EPOCH[498] - STEP[120]
# Generator_loss:7.2045
# L1_loss:0.1201
# Discriminator_loss:0.0078
#
# EPOCH[498] - STEP[140]
# Generator_loss:6.2517
# L1_loss:0.1095
# Discriminator_loss:0.0961
#
# EPOCH[498] - STEP[160]
# Generator_loss:4.1375
# L1_loss:0.1145
# Discriminator_loss:0.0423
#
# EPOCH[498] - STEP[180]
# Generator_loss:4.9510
# L1_loss:0.1458
# Discriminator_loss:0.0355
#
# EPOCH[498] - STEP[200]
# Generator_loss:6.1272
# L1_loss:0.1402
# Discriminator_loss:0.0088
#
# EPOCH[498] - STEP[220]
# Generator_loss:2.5355
# L1_loss:0.1102
# Discriminator_loss:0.2240
#
# EPOCH[498] - STEP[240]
# Generator_loss:4.0631
# L1_loss:0.1061
# Discriminator_loss:0.0391
#
# EPOCH[499] - STEP[20]
# Generator_loss:4.1533
# L1_loss:0.1343
# Discriminator_loss:0.0375
#
# EPOCH[499] - STEP[40]
# Generator_loss:6.0196
# L1_loss:0.1117
# Discriminator_loss:0.1533
#
# EPOCH[499] - STEP[60]
# Generator_loss:2.8547
# L1_loss:0.0954
# Discriminator_loss:0.1147
#
# EPOCH[499] - STEP[80]
# Generator_loss:4.7526
# L1_loss:0.1054
# Discriminator_loss:0.0225
#
# EPOCH[499] - STEP[100]
# Generator_loss:5.9588
# L1_loss:0.1861
# Discriminator_loss:0.0639
#
# EPOCH[499] - STEP[120]
# Generator_loss:5.6005
# L1_loss:0.1359
# Discriminator_loss:0.0103
#
# EPOCH[499] - STEP[140]
# Generator_loss:4.3080
# L1_loss:0.0922
# Discriminator_loss:0.7929
#
# EPOCH[499] - STEP[160]
# Generator_loss:0.4858
# L1_loss:0.1071
# Discriminator_loss:1.4759
#
# EPOCH[499] - STEP[180]
# Generator_loss:1.1176
# L1_loss:0.0965
# Discriminator_loss:0.8556
#
# EPOCH[499] - STEP[200]
# Generator_loss:6.7993
# L1_loss:0.1445
# Discriminator_loss:0.0039
#
# EPOCH[499] - STEP[220]
# Generator_loss:4.1287
# L1_loss:0.0924
# Discriminator_loss:0.0939
#
# EPOCH[499] - STEP[240]
# Generator_loss:4.2103
# L1_loss:0.1090
# Discriminator_loss:0.0372
#
# EPOCH[500] - STEP[20]
# Generator_loss:3.2492
# L1_loss:0.1041
# Discriminator_loss:0.1196
#
# EPOCH[500] - STEP[40]
# Generator_loss:3.7510
# L1_loss:0.1307
# Discriminator_loss:0.0607
#
# EPOCH[500] - STEP[60]
# Generator_loss:1.4526
# L1_loss:0.0932
# Discriminator_loss:0.4849
#
# EPOCH[500] - STEP[80]
# Generator_loss:4.2716
# L1_loss:0.1182
# Discriminator_loss:0.6936
#
# EPOCH[500] - STEP[100]
# Generator_loss:1.8003
# L1_loss:0.1312
# Discriminator_loss:0.3519
#
# EPOCH[500] - STEP[120]
# Generator_loss:8.8801
# L1_loss:0.0932
# Discriminator_loss:0.0231
#
# EPOCH[500] - STEP[140]
# Generator_loss:5.2766
# L1_loss:0.1308
# Discriminator_loss:0.0224
#
# EPOCH[500] - STEP[160]
# Generator_loss:1.8508
# L1_loss:0.1259
# Discriminator_loss:0.3956
#
# EPOCH[500] - STEP[180]
# Generator_loss:3.7126
# L1_loss:0.1036
# Discriminator_loss:0.2663
#
# EPOCH[500] - STEP[200]
# Generator_loss:4.8007
# L1_loss:0.1157
# Discriminator_loss:0.0416
#
# EPOCH[500] - STEP[220]
# Generator_loss:4.5513
# L1_loss:0.1235
# Discriminator_loss:0.1074
#
# EPOCH[500] - STEP[240]
# Generator_loss:2.4385
# L1_loss:0.1139
# Discriminator_loss:0.2765

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, original = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))

plt.subplot(1,3,1); plt.imshow(denormalize(original)); plt.title('sketch', fontsize=20)
plt.subplot(1,3,2); plt.imshow(pred[0]); plt.title('generated photo', fontsize=20)
plt.subplot(1,3,3); plt.imshow(denormalize(sketch)); plt.title('original photo', fontsize=20)
# Out:
# Text(0.5, 1.0, 'original photo')

# %%
|
